# %% [markdown]
# # 산점도 그리기

# %%
pip install gdown
# Out:
# Collecting gdown
#   Downloading gdown-4.7.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: filelock in c:\users\khj\anaconda3\lib\site-packages (from gdown) (3.9.0)
# Requirement already satisfied: requests[socks] in c:\users\khj\anaconda3\lib\site-packages (from gdown) (2.29.0)
# Requirement already satisfied: six in c:\users\khj\anaconda3\lib\site-packages (from gdown) (1.16.0)
# Requirement already satisfied: tqdm in c:\users\khj\anaconda3\lib\site-packages (from gdown) (4.65.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\khj\anaconda3\lib\site-packages (from gdown) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\khj\anaconda3\lib\site-packages (from beautifulsoup4->gdown) (2.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\khj\anaconda3\lib\site-packages (from requests[socks]->gdown) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\khj\anaconda3\lib\site-packages (from requests[socks]->gdown) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\khj\anaconda3\lib\site-packages (from requests[socks]->gdown) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\khj\anaconda3\lib\site-packages (from requests[socks]->gdown) (2023.5.7)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\khj\anaconda3\lib\site-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: colorama in c:\users\khj\anaconda3\lib\site-packages (from tqdm->gdown) (0.4.6)
# Installing collected packages: gdown
# Successfully installed gdown-4.7.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import gdown
gdown.download('https://bit.ly/3pK7iuu','ns_book7.csv',quiet=False)
# Out:
# Downloading...
# From: https://bit.ly/3pK7iuu
# To: C:\Users\khj\데이터분석\ns_book7.csv
# 100%|█████████████████████████████████████████████████████████████████████████████| 53.8M/53.8M [00:02<00:00, 20.6MB/s]
# 'ns_book7.csv'

# %%
import pandas as pd
ns_book7 = pd.read_csv('ns_book7.csv', low_memory=False)
ns_book7.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter([1,2,3,4],[1,2,3,4])
plt.show()

# %%
plt.scatter(ns_book7['번호'], ns_book7['대출건수'])
plt.show()

# %%
plt.scatter(ns_book7['도서권수'], ns_book7['대출건수'])
plt.show()

# %%
plt.scatter(ns_book7['도서권수'], ns_book7['대출건수'], alpha=0.1)
plt.show()

# %%
average_borrows = ns_book7['대출건수']/ns_book7['도서권수']
plt.scatter(average_borrows, ns_book7['대출건수'], alpha=0.1)
plt.show()

# %% [markdown]
# # 히스토그램 그리기

# %%
plt.hist([0,3,5,6,7,7,9,13], bins=5)
plt.show()

# %%
import numpy as np
np.histogram_bin_edges([0,3,5,6,7,7,9,13], bins=5)
# Out:
# array([ 0. ,  2.6,  5.2,  7.8, 10.4, 13. ])

# %%
np.random.seed(42)
random_samples = np.random.randn(1000)

# %%
print(np.mean(random_samples), np.std(random_samples))
# Out:
# 0.01933205582232549 0.9787262077473543

# %%
plt.hist(random_samples)
plt.show()

# %%
plt.hist(ns_book7['대출건수'])
plt.show()

# %%
plt.hist(ns_book7['대출건수'])
plt.yscale('log')
plt.show()

# %%
plt.hist(ns_book7['대출건수'], bins=1000)
plt.yscale('log')
plt.show()

# %%
title_len = ns_book7['도서명'].apply(len)
plt.hist(title_len, bins=100)
plt.show()

# %%
plt.hist(title_len, bins=100)
plt.xscale('log')
plt.show()

# %% [markdown]
# # 상자 수염 그림 그리기

# %%
plt.boxplot(ns_book7[['대출건수','도서권수']])
plt.show()

# %%
plt.boxplot(ns_book7[['대출건수','도서권수']])
plt.yscale('log')
plt.show()

# %%
plt.boxplot(ns_book7[['대출건수','도서권수']], vert=False)
plt.xscale('log')
plt.show()

# %%
plt.boxplot(ns_book7[['대출건수','도서권수']], whis=10)
plt.yscale('log')
plt.show()

# %%
plt.boxplot(ns_book7[['대출건수','도서권수']], whis=(0,100))
plt.yscale('log')
plt.show()

# %% [markdown]
# # 통계량을 시각적으로 표현하기

# %%
ns_book7.plot.scatter('도서권수','대출건수',alpha=0.1)
plt.show()
# Out:
# C:\Users\khj\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\khj\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\khj\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44428 (\N{HANGUL SYLLABLE GWEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\khj\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\khj\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\khj\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 52636 (\N{HANGUL SYLLABLE CUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\khj\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44148 (\N{HANGUL SYLLABLE GEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
ns_book7['도서명'].apply(len).plot.hist(bins=100)
plt.show()

# %%
ns_book7[['대출건수','도서권수']].boxplot()
plt.yscale('log')
plt.show()
# Out:
# C:\Users\khj\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\khj\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 52636 (\N{HANGUL SYLLABLE CUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\khj\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44148 (\N{HANGUL SYLLABLE GEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\khj\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\khj\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\khj\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\khj\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44428 (\N{HANGUL SYLLABLE GWEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
