# %%
import gdown
gdown.download('https://bit.ly/3eeMKZ', '남산도서관 장서 대출목록 (2023년 04월).csv', quiet=False)
# Out:
# Downloading...
# From: https://bit.ly/3eeMKZ
# To: C:\Users\kimheonju\데이터분석\남산도서관 장서 대출목록 (2023년 04월).csv
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 5.19k/5.19k [00:00<?, ?B/s]
# '남산도서관 장서 대출목록 (2023년 04월).csv'

# %%
import chardet
with open('남산도서관 장서 대출목록 (2023년 04월).csv', mode='rb') as f:
    d = f.readline()
print(chardet.detect(d))
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}

# %%
with open('남산도서관 장서 대출목록 (2023년 04월).csv', encoding='EUC-KR') as f:
    print(f.readline())
    print(f.readline())
# Out:
# 번호,도서명,저자,출판사,발행년도,ISBN,세트 ISBN,부가기호,권,주제분류번호,도서권수,대출건수,등록일자,
#
# "1","별자리 오디세이","우주살롱 (지은이)","비엠케이(BMK)","2023","9791189703547","","","","","1","0","2023-04-28",

# %%
import pandas as pd
df = pd.read_csv('남산도서관 장서 대출목록 (2023년 04월).csv', encoding='EUC-KR')
# Out:
# C:\Users\kimheonju\AppData\Local\Temp\ipykernel_24400\1066672642.py:2: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('남산도서관 장서 대출목록 (2023년 04월).csv', encoding='EUC-KR')

# %%
df = pd.read_csv('남산도서관 장서 대출목록 (2023년 04월).csv', encoding='EUC-KR', low_memory=False)

# %%
df.head()
# Out:
#    번호                  도서명                        저자        출판사  발행년도  \
# 0   1             별자리 오디세이                우주살롱 (지은이)  비엠케이(BMK)  2023
# 1   2             하얀 마물의 탑   미쓰다 신조 (지은이), 민경욱 (옮긴이)         비채  2023
# 2   3               디 아더 유  J. S. 먼로 (지은이),지여울 (옮긴이)      소미미디어  2023
# 3   4               죽음의 가시  시마오 도시오 (지은이), 이종은 (옮긴이)     문학과지성사  2023
# 4   5  왕초보, 부동산 어떻게 투자할까요?                 부찾남 (지은이)       다산북스  2023
#
#             ISBN  세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자  \
# 0  9791189703547      NaN  NaN  NaN    NaN     1     0  2023-04-28
# 1  9788934943853      NaN  NaN  NaN    NaN     1     0  2023-04-28
# 2  9791138478281      NaN  NaN  NaN    NaN     1     0  2023-04-28
# 3  9788932041445      NaN  NaN  NaN    NaN     1     0  2023-04-28
# 4  9791130642420      NaN  NaN  NaN    NaN     1     0  2023-04-28
#
#    Unnamed: 13
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df.to_csv('ns_202304.csv')

# %%
with open('ns_202304.csv',encoding='utf-8') as f:
    for i in range(3):
        print(f.readline(), end='')
# Out:
# ,번호,도서명,저자,출판사,발행년도,ISBN,세트 ISBN,부가기호,권,주제분류번호,도서권수,대출건수,등록일자,Unnamed: 13
# 0,1,별자리 오디세이,우주살롱 (지은이),비엠케이(BMK),2023,9791189703547,,,,,1,0,2023-04-28,
# 1,2,하얀 마물의 탑,"미쓰다 신조 (지은이), 민경욱 (옮긴이)",비채,2023,9788934943853,,,,,1,0,2023-04-28,

# %%
ns_df = pd.read_csv('ns_202304.csv', low_memory=False)
ns_df.head()
# Out:
#    Unnamed: 0  번호                  도서명                        저자        출판사  \
# 0           0   1             별자리 오디세이                우주살롱 (지은이)  비엠케이(BMK)
# 1           1   2             하얀 마물의 탑   미쓰다 신조 (지은이), 민경욱 (옮긴이)         비채
# 2           2   3               디 아더 유  J. S. 먼로 (지은이),지여울 (옮긴이)      소미미디어
# 3           3   4               죽음의 가시  시마오 도시오 (지은이), 이종은 (옮긴이)     문학과지성사
# 4           4   5  왕초보, 부동산 어떻게 투자할까요?                 부찾남 (지은이)       다산북스
#
#    발행년도           ISBN  세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자  \
# 0  2023  9791189703547      NaN  NaN  NaN    NaN     1     0  2023-04-28
# 1  2023  9788934943853      NaN  NaN  NaN    NaN     1     0  2023-04-28
# 2  2023  9791138478281      NaN  NaN  NaN    NaN     1     0  2023-04-28
# 3  2023  9788932041445      NaN  NaN  NaN    NaN     1     0  2023-04-28
# 4  2023  9791130642420      NaN  NaN  NaN    NaN     1     0  2023-04-28
#
#    Unnamed: 13
# 0          NaN
# 1          NaN
# 2          NaN
# ...

# %%
ns_df = pd.read_csv('ns_202304.csv', index_col=0, low_memory=False)
ns_df.head()
# Out:
#    번호                  도서명                        저자        출판사  발행년도  \
# 0   1             별자리 오디세이                우주살롱 (지은이)  비엠케이(BMK)  2023
# 1   2             하얀 마물의 탑   미쓰다 신조 (지은이), 민경욱 (옮긴이)         비채  2023
# 2   3               디 아더 유  J. S. 먼로 (지은이),지여울 (옮긴이)      소미미디어  2023
# 3   4               죽음의 가시  시마오 도시오 (지은이), 이종은 (옮긴이)     문학과지성사  2023
# 4   5  왕초보, 부동산 어떻게 투자할까요?                 부찾남 (지은이)       다산북스  2023
#
#             ISBN  세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자  \
# 0  9791189703547      NaN  NaN  NaN    NaN     1     0  2023-04-28
# 1  9788934943853      NaN  NaN  NaN    NaN     1     0  2023-04-28
# 2  9791138478281      NaN  NaN  NaN    NaN     1     0  2023-04-28
# 3  9788932041445      NaN  NaN  NaN    NaN     1     0  2023-04-28
# 4  9791130642420      NaN  NaN  NaN    NaN     1     0  2023-04-28
#
#    Unnamed: 13
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df.to_csv('ns_202304.csv', index=False)
